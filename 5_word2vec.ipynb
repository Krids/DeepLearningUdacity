# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
#from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'term', 'a', 'as', 'originated', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.457321
# Nearest to can: missionaries, wished, duplicating, selectable, blocs, simplifications, supersede, lussac,
# Nearest to american: evans, anecdote, lipid, beria, rana, accra, bulgars, gdi,
# Nearest to an: dioxin, mohr, subcommittee, auditum, doom, maggots, palazzo, pus,
# Nearest to which: operatives, uncharacteristic, turin, bec, venue, agar, tallow, dawning,
# Nearest to at: egmont, generating, rape, apc, heading, colorful, gaians, obsoletes,
# Nearest to as: toto, relocation, pouch, armada, batters, manchus, shaanxi, vogt,
# Nearest to of: zwickau, mai, traditions, miscellany, arbitrary, mesoamerica, jewellery, disadvantageous,
# Nearest to were: hosted, predate, watchmen, lavishly, refrigerators, tur, emphasizes, wrists,
# Nearest to not: ach, hay, anjou, perspective, willy, perceptive, blond, adolf,
# Nearest to world: tethys, lynda, rovere, defaulted, renaissance, logically, journals, gerrymandering,
# Nearest to about: ulvaeus, archived, disregard, cca, ocean, neuro, heywood, aide,
# Nearest to zero: theorize, begins, cyborgs, uppercase, moderne, ayahuasca, schirra, larry,
# Nearest to and: ajaccio, stamp, cave, bataan, feasible, buys, roh, cryopreservation,
# Nearest to two: inc, props, infamy, eurostar, spectroscopy, dcs, metrology, sigma,
# Nearest to most: buddy, extremely, tabasco, waned, viewers, schooled, duffy, mercia,
# Nearest to use: deviant, sseldorf, crustaceans, philosophers, shackleton, laconia, stagecoach, arnaz,
# Average loss at step 2000: 4.369354
# Average loss at step 4000: 3.865021
# Average loss at step 6000: 3.792598
# Average loss at step 8000: 3.690185
# Average loss at step 10000: 3.620992
# Nearest to can: may, could, would, must, will, garden, simplifications, duplicating,
# Nearest to american: gigante, gdi, lipid, and, villagers, rana, hel, evans,
# Nearest to an: corrosion, known, auditum, rahman, maggots, keaton, the, lettre,
# Nearest to which: this, also, that, it, who, foreshadowing, bouncer, completed,
# Nearest to at: in, heading, suspending, unbeaten, canossa, tangled, same, on,
# Nearest to as: by, with, universitet, nontrivial, without, winer, pantera, relocation,
# Nearest to of: in, and, usages, indefatigable, for, latitudes, acquiescence, montju,
# Nearest to were: are, was, had, wand, be, rosebud, impedes, have,
# Nearest to not: they, it, there, scandalous, he, hay, to, perspective,
# Nearest to world: defaulted, rovere, tethys, lynda, isometric, evolutionary, hemp, bearing,
# Nearest to about: aide, ocean, ulvaeus, dalhousie, pupils, premature, fugitive, demigod,
# Nearest to zero: nine, five, eight, six, seven, four, three, two,
# Nearest to and: or, who, s, dramatization, hco, in, of, alh,
# Nearest to two: three, four, six, five, eight, one, seven, nine,
# Nearest to most: all, extremely, impulsive, buddy, duffy, ecclesia, schooled, focused,
# Nearest to use: deviant, laconia, churches, plugging, luxuries, philosophers, newtons, epicureanism,
# Average loss at step 12000: 3.602181
# Average loss at step 14000: 3.577769
# Average loss at step 16000: 3.409950
# Average loss at step 18000: 3.459956
# Average loss at step 20000: 3.539947
# Nearest to can: may, could, would, will, must, might, should, to,
# Nearest to american: british, german, gigante, villagers, french, rana, genetics, lipid,
# Nearest to an: known, trinomial, corrosion, cricket, ola, the, dioxin, pronouns,
# Nearest to which: that, this, who, also, it, there, these, but,
# Nearest to at: in, heading, on, and, tangled, during, under, with,
# Nearest to as: toto, robb, without, winer, nietzsche, acquainted, pouch, batters,
# Nearest to of: montju, for, miscellany, transubstantiation, paddy, anorexia, erudite, usages,
# Nearest to were: are, had, was, have, while, be, been, wand,
# Nearest to not: it, they, also, diuretics, we, muons, never, hay,
# Nearest to world: rovere, defaulted, tethys, jockey, evolutionary, callers, god, lynda,
# Nearest to about: pupils, dalhousie, cca, learns, amigaos, between, ocean, correlates,
# Nearest to zero: five, six, nine, seven, eight, four, three, two,
# Nearest to and: or, but, which, in, at, complimentary, flagpole, lombardo,
# Nearest to two: five, four, three, six, eight, seven, one, nine,
# Nearest to most: more, all, some, extremely, ecclesia, many, schooled, archers,
# Nearest to use: deviant, laconia, churches, newtons, attributed, luxuries, jesus, pitches,
# Average loss at step 22000: 3.503716
# Average loss at step 24000: 3.492057
# Average loss at step 26000: 3.482251
# Average loss at step 28000: 3.483140
# Average loss at step 30000: 3.499966
# Nearest to can: may, would, could, will, must, might, should, to,
# Nearest to american: british, german, italian, swedish, rana, english, french, gigante,
# Nearest to an: corrosion, lettre, pronouns, windmill, cricket, warlord, ola, efron,
# Nearest to which: this, that, it, who, but, also, these, standardize,
# Nearest to at: in, during, on, under, after, heading, around, tangled,
# Nearest to as: toto, nontrivial, winer, robb, when, became, kaunda, without,
# Nearest to of: in, montju, latitudes, from, aboriginal, embargo, for, jewish,
# Nearest to were: are, was, have, had, is, been, those, be,
# Nearest to not: they, still, there, generally, typically, we, spun, also,
# Nearest to world: rovere, defaulted, story, jehoiakim, ineffectiveness, ottoman, evolutionary, hicks,
# Nearest to about: between, amigaos, argand, correlates, carpathians, pupils, tempos, ulvaeus,
# Nearest to zero: five, seven, eight, nine, four, six, three, two,
# Nearest to and: or, but, in, dominican, who, triadic, against, however,
# Nearest to two: four, one, three, five, six, seven, eight, nine,
# Nearest to most: more, ecclesia, extremely, some, many, all, schooled, archers,
# Nearest to use: churches, newtons, laconia, intermittently, luxuries, telekinetic, deviant, management,
# Average loss at step 32000: 3.501517
# Average loss at step 34000: 3.492189
# Average loss at step 36000: 3.454412
# Average loss at step 38000: 3.304880
# Average loss at step 40000: 3.435420
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to american: british, japanese, german, french, italian, australian, swedish, english,
# Nearest to an: corrosion, efron, trinomial, shalom, cricket, the, kurtosis, dreadnoughts,
# Nearest to which: that, this, also, who, there, it, these, still,
# Nearest to at: during, in, on, eradication, heading, tangled, ascertain, agrippa,
# Nearest to as: toto, by, winer, kaunda, robb, is, bayan, when,
# Nearest to of: in, devas, jewellery, sanctify, for, from, including, leviathan,
# Nearest to were: are, have, was, had, while, been, be, many,
# Nearest to not: they, it, still, often, also, spun, only, typically,
# Nearest to world: rovere, lynda, defaulted, ineffectiveness, metamorphoses, dahomey, evolutionary, circumcising,
# Nearest to about: between, argand, extractor, amigaos, correlates, on, neuro, ulvaeus,
# Nearest to zero: seven, nine, five, eight, six, four, three, two,
# Nearest to and: or, agouti, but, including, designates, huguenot, however, like,
# Nearest to two: three, four, five, six, seven, one, eight, nine,
# Nearest to most: more, ecclesia, many, extremely, less, schooled, some, archers,
# Nearest to use: churches, newtons, chimera, epistles, laconia, psychiatrists, luxuries, attributed,
# Average loss at step 42000: 3.438648
# Average loss at step 44000: 3.454548
# Average loss at step 46000: 3.449572
# Average loss at step 48000: 3.355677
# Average loss at step 50000: 3.386830
# Nearest to can: could, may, would, must, will, should, might, cannot,
# Nearest to american: japanese, australian, french, italian, swedish, british, german, english,
# Nearest to an: shalom, corrosion, maggots, desilu, the, windmill, efron, creighton,
# Nearest to which: that, this, also, who, standardize, there, it, what,
# Nearest to at: during, in, on, under, heading, around, near, ascertain,
# Nearest to as: by, winer, became, inferential, slaughter, herzl, robb, is,
# Nearest to of: in, entire, and, including, devas, during, uppermost, moat,
# Nearest to were: are, was, have, had, yacht, be, been, is,
# Nearest to not: they, never, generally, diuretics, still, spun, often, it,
# Nearest to world: metamorphoses, rovere, cistercians, circumcising, affirm, abyssinia, technician, originators,
# Nearest to about: extractor, ulvaeus, correlates, argand, between, pupils, neuro, mauro,
# Nearest to zero: nine, seven, eight, five, four, six, three, two,
# Nearest to and: or, but, like, of, however, including, than, proportionate,
# Nearest to two: three, six, seven, four, one, eight, five, nine,
# Nearest to most: more, many, ecclesia, less, extremely, some, schooled, both,
# Nearest to use: newtons, churches, kind, laconia, course, luxuries, psychiatrists, gravesite,
# Average loss at step 52000: 3.438293
# Average loss at step 54000: 3.427824
# Average loss at step 56000: 3.438002
# Average loss at step 58000: 3.395716
# Average loss at step 60000: 3.398688
# Nearest to can: may, could, must, will, would, might, should, cannot,
# Nearest to american: australian, british, swedish, japanese, french, german, italian, english,
# Nearest to an: corrosion, creighton, repositories, shalom, trinomial, maggots, ubiquitous, the,
# Nearest to which: that, this, it, what, these, who, but, however,
# Nearest to at: in, during, near, under, tool, heading, entire, slings,
# Nearest to as: nontrivial, winer, considered, better, toto, robb, miranda, mandolins,
# Nearest to of: for, in, including, devas, like, societal, usages, perturbed,
# Nearest to were: are, was, have, had, been, while, be, including,
# Nearest to not: still, spun, generally, there, never, typically, they, actually,
# Nearest to world: ineffectiveness, metamorphoses, stratton, cistercians, whereas, technician, affirm, shrews,
# Nearest to about: extractor, neuro, mauro, ulvaeus, argand, paulist, over, pupils,
# Nearest to zero: five, four, eight, seven, six, nine, three, two,
# Nearest to and: or, but, although, while, however, archaically, mandolins, like,
# Nearest to two: three, five, four, six, one, seven, eight, zero,
# Nearest to most: many, more, ecclesia, some, less, extremely, particularly, schooled,
# Nearest to use: churches, newtons, kind, luxuries, retire, laconia, perpetrator, responsibility,
# Average loss at step 62000: 3.244612
# Average loss at step 64000: 3.254670
# Average loss at step 66000: 3.405361
# Average loss at step 68000: 3.394270
# Average loss at step 70000: 3.360844
# Nearest to can: may, could, must, will, would, should, might, cannot,
# Nearest to american: british, australian, french, english, japanese, italian, swedish, grove,
# Nearest to an: corrosion, the, shalom, windmill, trinomial, ubiquitous, gions, warlord,
# Nearest to which: that, this, also, but, who, still, what, these,
# Nearest to at: during, tool, near, kilmer, around, impurity, traditionally, after,
# Nearest to as: winer, nontrivial, geo, batters, is, kaunda, oubangui, when,
# Nearest to of: including, include, latest, sacrificial, and, outlived, original, like,
# Nearest to were: are, was, have, be, had, been, while, including,
# Nearest to not: still, generally, never, spun, usually, typically, actually, they,
# Nearest to world: ineffectiveness, centimes, cistercians, technician, stratton, behold, peloponnesian, omotic,
# Nearest to about: extractor, mauro, over, paulist, ulvaeus, meditator, pupils, on,
# Nearest to zero: five, six, four, eight, nine, seven, three, two,
# Nearest to and: or, but, while, including, anastasio, like, complimentary, include,
# Nearest to two: three, four, six, five, seven, one, eight, zero,
# Nearest to most: more, many, less, extremely, ecclesia, schooled, some, both,
# Nearest to use: cause, retire, form, usage, luxuries, allow, strategists, kind,
# Average loss at step 72000: 3.368678
# Average loss at step 74000: 3.352029
# Average loss at step 76000: 3.316580
# Average loss at step 78000: 3.352624
# Average loss at step 80000: 3.372264
# Nearest to can: may, could, will, must, would, might, cannot, should,
# Nearest to american: british, australian, french, canadian, japanese, italian, international, swedish,
# Nearest to an: corrosion, lettre, efron, aeroplanes, maggots, windmill, caleb, repositories,
# Nearest to which: that, this, what, but, usually, also, who, there,
# Nearest to at: during, in, on, muster, hopeless, around, traditionally, under,
# Nearest to as: reelected, winer, robb, nontrivial, proficiency, slaughter, batters, before,
# Nearest to of: including, keefe, in, jewellery, soto, pelias, plea, kiosk,
# Nearest to were: are, was, had, have, been, being, although, those,
# Nearest to not: still, never, generally, usually, we, typically, spun, actually,
# Nearest to world: behold, ineffectiveness, technician, registers, cistercians, peloponnesian, ronstadt, graz,
# Nearest to about: extractor, aug, over, paulist, mauro, correlates, kai, gwh,
# Nearest to zero: five, seven, six, nine, eight, four, three, two,
# Nearest to and: or, but, while, nebula, than, miranda, mpeg, timberlake,
# Nearest to two: three, four, five, six, seven, one, eight, zero,
# Nearest to most: more, many, less, some, schooled, particularly, ecclesia, extremely,
# Nearest to use: support, cause, because, perpetrator, luxuries, chimera, form, newtons,
# Average loss at step 82000: 3.409777
# Average loss at step 84000: 3.413907
# Average loss at step 86000: 3.389289
# Average loss at step 88000: 3.359304
# Average loss at step 90000: 3.361197
# Nearest to can: may, could, must, will, might, would, should, cannot,
# Nearest to american: british, french, australian, canadian, japanese, italian, english, german,
# Nearest to an: efron, corrosion, ubiquitous, trinomial, maggots, windmill, leapt, hobbies,
# Nearest to which: that, this, also, what, who, these, there, actually,
# Nearest to at: on, during, under, near, in, around, against, after,
# Nearest to as: winer, robb, toto, falsehood, miranda, geo, nontrivial, slaughter,
# Nearest to of: including, for, under, in, oversees, and, cognitivism, original,
# Nearest to were: are, had, have, was, while, although, these, lun,
# Nearest to not: still, never, we, generally, actually, also, spun, indemnity,
# Nearest to world: peloponnesian, ineffectiveness, doc, denomination, silla, technician, metamorphoses, centimes,
# Nearest to about: ulvaeus, extractor, mauro, aug, kai, paulist, correlates, friends,
# Nearest to zero: five, eight, seven, nine, six, four, three, two,
# Nearest to and: or, but, while, including, however, tricking, although, hmos,
# Nearest to two: three, four, five, seven, six, eight, one, zero,
# Nearest to most: many, less, more, some, ecclesia, especially, particularly, both,
# Nearest to use: support, course, responsibility, kind, importance, users, because, newtons,
# Average loss at step 92000: 3.399182
# Average loss at step 94000: 3.256806
# Average loss at step 96000: 3.359954
# Average loss at step 98000: 3.241044
# Average loss at step 100000: 3.357593
# Nearest to can: could, may, must, will, would, might, should, cannot,
# Nearest to american: british, french, australian, german, canadian, italian, indian, albania,
# Nearest to an: another, corrosion, efron, shalom, maggots, hobbies, diabetic, windmill,
# Nearest to which: that, this, what, who, usually, actually, but, often,
# Nearest to at: in, during, on, near, under, hopeless, tangled, from,
# Nearest to as: winer, robb, like, honeymoon, when, emanate, fuze, pantera,
# Nearest to of: including, in, and, whose, protege, jewellery, latest, original,
# Nearest to were: are, was, have, these, had, been, those, be,
# Nearest to not: never, still, almost, generally, actually, they, you, i,
# Nearest to world: peloponnesian, cistercians, ineffectiveness, silla, doc, trismegistus, metamorphoses, story,
# Nearest to about: extractor, ulvaeus, mauro, meditator, succeeding, leffler, paulist, friends,
# Nearest to zero: five, eight, six, nine, seven, four, three, two,
# Nearest to and: or, but, while, like, although, however, including, burgh,
# Nearest to two: three, six, four, five, seven, eight, one, zero,
# Nearest to most: more, less, ecclesia, extremely, some, especially, many, particularly,
# Nearest to use: support, kind, usage, cause, form, amount, collapse, responsibility,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
